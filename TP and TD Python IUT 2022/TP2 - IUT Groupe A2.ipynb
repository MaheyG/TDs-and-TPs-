# %% [markdown]
# <button type="button" class="btn btn-primary btn-lg btn-block"><h2><div align="center">TP 2 : Fonctions
#     </div></h2></button>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 1 </i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Rappelez les intérêts à faire une fonction
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# A quoi sert le `def` en python
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# Quelle est la différence entre `print` et `return` dans une fonction.
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Corrigez le code suivant, qui calcule f(g(x))
# </div>

# %%
def f(x) :
    print(x-5)
    
    
def g(x) :
    print(x**3)

a=3
print(f(g(a)))
# Out:
# 22

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#  Ecrire une 3ème fonctions $h(x)=-|x|$ qui donne moins la valeur absolue de x et calculer h(f(g(1)))
#
#  Vous pouvez utilisez la fonction ```abs()```
# </div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# Ecrire une fonction `type_list` qui prend une liste en argument et qui $\textbf{retourne}$ une liste composée du type de chaque élément de la liste. Vous pouvez vous aidez de la fonction (déjà implémentée) `type()`.
#
# Par exemple `type_list([0,'oui',[1,2,3],True,3.14]) ` doit renvoyer `[int,str,list,bool,float]`. Testez votre fonction `type_list` avec cet exemple.
# </div>

# %%
type_list([0,'oui',[1,2,3],True,3.14])
# Out:
# [int, str, list, bool, float]

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# Ecrire une 2ème fonction `concat` qui prend 2 listes de même taille en arguments (vérifiez quelles sont bien de même tailles) et qui $\textbf{retourne}$ en liste le premier élément de la 1ère liste puis le 1er élément de la 2ème liste puis le 2ème élément de la première liste etc...
#
# Par exemple `concat([1,2,3],['a','b','c'])=[ 1,'a',2,'b',3,'c']` . Testez votre fonction sur cet exemple
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# Ecrire une 3ème fonction  `type_concat` qui prend en argument une liste et qui $\textbf{retourne}$ une liste avec les éléments de la liste suivis de leurs type.
#
# Par exemple `type_concat([14,'a',True])=[int,str,bool]`
#
# Aidez vous des deux fonctions précédements utilisées.
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Ecrire une 4ème fonction qui prend en argument une liste et qui $\textbf{retourne}$ tout les types contenues dans cette liste (sans répétition).
#
# Par exemple `f([12,'oui',1])=[int,str]`
# </div>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 3 : Porté des Noms</i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Expliquez la différence entre une variable locale et une variable globale.
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Corrigez le code suivant
# </div>

# %%
#On veut calculer 3x-5 avec a=1 puis b=5
def carre(x) :
    x=1
    print(3x-5)

a=1
carre(a)
b=5
carre(b)
# Out:
# 1
# 1

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Dans le code précédent, quelles sont les variables locales et les variables globales?
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Corrigez le code suivant :
#
# </div>

# %%
def puissance(b,a):
    print(a**b)

# On cherche à calculer 5^2=25    
a= 5
b= 2
puissance(5,2)
# Out:
# 32

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 3 : Arguments</i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Rappelez comment écrire une fonction qui prend un nombre arbitraire d'arguments
#
# </div>

# %% [markdown]
# ## Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# Ecrire une fonction qui prend un nombre arbitraire de nombre et qui `print` la multiplication des  ces nombres
#     .
#
# Vérifiez que les arguements sont bien des `int` ou `float ` renvoyez un message d'erreur sinon.
#
# </div>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 3 : Tris</i></div></h4></button>

# %% [markdown]
# On s'intéresse au problème de trier une liste de nombre entier dans l'ordre croissant.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
# Ecrire une fonction `compare` qui compare 2 nombres et qui les retourne (en tuple) dans l'ordre croissant.
#
# Par exemple `compare(13,2)=(2,13) ` et `compare(1,2)=(1,2)`
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# Ecrire une fonction `compare_list` qui prend en argument une liste de nombre et qui place le premier élément de la liste à gauche du premier nombre plus grand que lui dans la liste.
#
# Par exemple `compare_list([1,5,-3])=[1,5,-3]` , `compare_list([10,6,-3,11])=[6,-3,10,11]`
#
# Si le premier élément n'a pas de plus grand nombre dans la liste, il est placé tout à droite : ` compare_list([99,0,1])=[0,1,99] `
#
# Vous pouvez vous aider de la fonction `compare`
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# Ecrire une fonction qui trie dans l'ordre croissant les éléments d'une liste de nombres.
# </div>
