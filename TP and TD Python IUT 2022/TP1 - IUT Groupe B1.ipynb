# %% [markdown]
# <button type="button" class="btn btn-primary btn-lg btn-block"><h2><div align="center">TP 1 : Groupe B1 </div></h2></button>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 1 : Types et Opérations</i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#
#   * Déclarer une variable ayant la valeur 34 et le type `int`
#
#   * Déclarer une variable ayant la valeur 34 et le type `float`
#
#   * Déclarer une variable ayant la valeur 34 et le type `string`
#
#   * Déclarer une variable ayant la valeur 34 et le type `list`
#
#    Vous pouvez vous aider de la fonction `type()`
# </div>

# %%
a = 
b =
c = 
d =

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   Corrigez le code suivant :
# </div>

# %%
a = input('saisissez un entier : ')
b = input('saisissez un 2e entier :')

a+=1
b-=1
inferieur == a<=b

print('a+1 =',a,' est plus grand ou égal à b-1 =',b,'? La réponse est :',not(inferieur))

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#  Quel est le type de la variable superieur ?
# </div>

# %% [markdown]
# ### Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   Expliquez la différence entre les deux afféctations suivante, et donnez leur type de chacune des variables :
# </div>

# %%
a = 1,618
b = 1.618

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   On répertorie des gens avec leurs prénom, ville de naissance, date de Naissance et si ils sont déjà aller au ski (True ou False)
# </div>

# %%
liste = ['Eric','Ajaccio',[17,'Août',1985],True]

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   Changer la ville de Naissance d'Eric par Lyon
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#
# Changer sa date d'anniversaire pour le 31 Août 1989
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   Ajoutez à la fin de la liste l'animal préféré d'Eric, qui est la tortue
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   Supprimer l'avant dernier élément de la liste
# </div>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 3 : if else elif</i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
#   Tout les nombres entiers sont soit pair soit impair, c'est à dire qu'ils s'écrivent soit$ n=2 \times p$ soit $n=2\times p + 1$. Le code suivant donne ce test de parité :
# </div>

# %%
n=int(input('saissisez un entier'))

if n % 2 == 0 :
    print("n est paire et il s'écrit ",n,'= 2 *', n//2)
else :
    print("n est impaire et il s'écrit",n,'= 2 *',n//2,"+1")

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# De la même manière, écrivez un code pour vérifiez si ils s'écrivent soit $n=3\times p$ soit $n=3\times p+1$ soit $n=3\times p+2$
# </div>

# %%
n=int(input('saissisez un entier'))

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 4 : Boucles while et for</i></div></h4></button>

# %% [markdown]
#  Partant de 2 éléments on peut dévinir la suite de Fibonnaci comme la somme des deux précédents termes de la suite.
# Mathématiquement
# $$x_n=x_{n-1}+x_{n-2}$$
#
# Par exemple partant de $x_0=0$ et $x_1=1$, les premiers termes de la suite sont :
# $$x_2=x_0+x_1=0+1=1$$
# $$x_3=x_1+x_2=1+1=2$$
# $$x_4=x_2+x_3=1+2=3$$
# $$x_5=x_3+x_4=2+3=5$$
# $$x_6=x_4+x_5=3+5=8$$

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Ecrivez un code qui print les 200 premiers termes de la suite de Fibonacci, avec $x_0=0$ et $x_1=1$
#
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#  Ecrivez un code qui donne print les éléments de la suite de Fibonnaci et qui s'arrête quand la suite dépasse 500 ($x_n>500$)
# </div>

# %%
# Copiez votre code précédent et complétez le ici.

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Ajoutez un compteur, qui compte le nombre d'itérations de la suite qu'il est nécéssaire de faire pour dépasser 500
# </div>

# %%
# Copiez votre code précédent et complétez le ici.

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Ecrire un code qui print les tables de multiplications de 1 à 10.
#
# Pour cela il faudrat utiliser les boucles imbriquées.
#
# </div>

# %% [markdown]
# <button type="button" class="btn btn-info btn-lg btn-block"><h4><div align="left"><i>Exercice 6 : Fonctions</i></div></h4></button>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Expliquez ce que fait la fonction suivante
#
# </div>

# %%
def fonction (n) :
    return n**2 +1

# %%
k=5
print(fonction(k))

# %% [markdown]
# ### Réponse :

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Ecrire une fonction qui retourne les n  premiers termes de la suite de Fibonnacci dans une liste. Avec paramètre $x_0$ et $x_1$ et $n$ (le nombre de termes à retourner)
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
#   Retournez dans une 2nd liste la valeur de $\frac{x_n}{x_{n-1}}$   à chaque itérations.
# </div>

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# La limite $\frac{x_n}{x_{n-1}}$ tend vers le nombre d'or $\simeq 1.618033...$. Ecrire une fonction approx(k,x_0,x_1) qui renvoie le nombre d'itérations de la suite de Fibonnaci nécéssaire pour approximer la k-ième décimal du nombre d'or.
# </div>

# %%
# Le nombre d'or est donné par :
nb_or = (1 + 5 ** 0.5) / 2
print(nb_or)

# L'approximation à la k-ième décimal est donnée par :
k=3
nb_or_approx = round(nb_or*10**k)/10**k
print(nb_or_approx)

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# Par exemple la première décimal est 1.6 qui est approximé par $\frac{x_n}{x_{n-1}}=\frac{5}{3}=1.6...$. La fonction doit renvoyer 5.
# </div>
